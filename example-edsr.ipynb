# %% [markdown]
# # EDSR

# %%
#pip install tensorflow #required only once

# %%
import os
import matplotlib.pyplot as plt

from data import DIV2K
from model.edsr import edsr
from train import EdsrTrainer

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-3b2f280627db> in <module>
#       4 from data import DIV2K
#       5 from model.edsr import edsr
# ----> 6 from train import EdsrTrainer
#       7
#       8 get_ipython().run_line_magic('matplotlib', 'inline')
#
# /content/gdrive/MyDrive/Collaborate /super-resolution-master/train.py in <module>
#       3
#       4 from model import evaluate
# ----> 5 from model import srgan
#       6
#       7 from tensorflow.keras.applications.vgg19 import preprocess_input
#
# /content/gdrive/MyDrive/Collaborate /super-resolution-master/model/srgan.py in <module>
# ----> 1 from tensorflow.python.keras.layers import Add, BatchNormalization, Conv2D, Dense, Flatten, Input, LeakyReLU, PReLU, Lambda
#       2 from tensorflow.python.keras.models import Model
#       3 from tensorflow.python.keras.applications.vgg19 import VGG19
#       4
#       5 from model.common import pixel_shuffle, normalize_01, normalize_m11, denormalize_m11
#
# ImportError: cannot import name 'BatchNormalization' from 'tensorflow.python.keras.layers' (/usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/layers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Number of residual blocks
depth = 16

# Super-resolution factor
scale = 4

# Downgrade operator
downgrade = 'bicubic'

# %%
# Location of model weights (needed for demo)
weights_dir = f'weights/edsr-{depth}-x{scale}'
weights_file = os.path.join(weights_dir, 'weights.h5')

os.makedirs(weights_dir, exist_ok=True)

# %% [markdown]
# ## Datasets
#
# You don't need to download the DIV2K dataset as the required parts are automatically downloaded by the `DIV2K` class. By default, DIV2K images are stored in folder `.div2k` in the project's root directory.

# %%
div2k_train = DIV2K(scale=scale, subset='train', downgrade=downgrade)
div2k_valid = DIV2K(scale=scale, subset='valid', downgrade=downgrade)

# %%
train_ds = div2k_train.dataset(batch_size=16, random_transform=True)
valid_ds = div2k_valid.dataset(batch_size=1, random_transform=False, repeat_count=1)

# %% [markdown]
# ## Training
#
# ### Pre-trained models
#
# If you want to skip training and directly run the demo below, download [weights-edsr-16-x4.tar.gz](https://martin-krasser.de/sisr/weights-edsr-16-x4.tar.gz) and extract the archive in the project's root directory. This will create a `weights/edsr-16-x4` directory containing the weights of the pre-trained model.

# %%
trainer = EdsrTrainer(model=edsr(scale=scale, num_res_blocks=depth), 
                      checkpoint_dir=f'.ckpt/edsr-{depth}-x{scale}')

# %%
# Train EDSR model for 300,000 steps and evaluate model
# every 1000 steps on the first 10 images of the DIV2K
# validation set. Save a checkpoint only if evaluation
# PSNR has improved.
trainer.train(train_ds,
              valid_ds.take(10),
              steps=300000, 
              evaluate_every=1000, 
              save_best_only=True)

# %%
# Restore from checkpoint with highest PSNR
trainer.restore()

# %%
# Evaluate model on full validation set
psnrv = trainer.evaluate(valid_ds)
print(f'PSNR = {psnrv.numpy():3f}')

# %%
# Save weights to separate location (needed for demo)
trainer.model.save_weights(weights_file)

# %% [markdown]
# ## Demo

# %%
model = edsr(scale=scale, num_res_blocks=depth)
model.load_weights(weights_file)

# %% [markdown]
# ### **used trained model, executed from after this line**

# %%
# !ls
# Out:
# article.ipynb  docs		   example-srgan.ipynb	model	     train.py
# data.py        environment.yml	   example-wdsr.ipynb	__pycache__  utils.py
# demo	       example-edsr.ipynb  LICENSE		README.md    weights

# %% [markdown]
# For setting up drive access and authentication, also changing directory

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# %cd gdrive/MyDrive/'Collaborate '/super-resolution-master
#! git pull
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Collaborate /super-resolution-master

# %%
from model import resolve_single
from utils import load_image, plot_sample

# %%
from model.edsr import edsr
model = edsr(scale=4, num_res_blocks=16)
model.load_weights('weights/edsr-16-x4/weights.h5')

# %%
def resolve_and_plot(lr_image_path):
    lr = load_image(lr_image_path)
    sr = resolve_single(model, lr)
    plot_sample(lr, sr)

# %%
resolve_and_plot('demo/0869x4-crop.png')

# %%
resolve_and_plot('demo/0829x4-crop.png')

# %%
resolve_and_plot('demo/0851x4-crop.png')
